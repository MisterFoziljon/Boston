# %%
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score as r2_score_sk
from Standard_Scaler import StandardScaler
from keras.models import load_model

# %%
model = load_model('model.h5')

# %%
data = pd.read_csv('Boston.csv')
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0    1.23247   0.0   8.14   0.0  0.538  6.142   91.7  3.9769   4.0  307.0
# 1    0.02177  82.5   2.03   0.0  0.415  7.610   15.7  6.2700   2.0  348.0
# 2    4.89822   0.0  18.10   0.0  0.631  4.970  100.0  1.3325  24.0  666.0
# 3    0.03961   0.0   5.19   0.0  0.515  6.037   34.5  5.9853   5.0  224.0
# 4    3.69311   0.0  18.10   0.0  0.713  6.376   88.4  2.5671  24.0  666.0
# ..       ...   ...    ...   ...    ...    ...    ...     ...   ...    ...
# 501  3.47428   0.0  18.10   1.0  0.718  8.780   82.9  1.9047  24.0  666.0
# 502  0.07896   0.0  12.83   0.0  0.437  6.273    6.0  4.2515   5.0  398.0
# 503  1.83377   0.0  19.58   1.0  0.605  7.802   98.2  2.0407   5.0  403.0
# 504  0.35809   0.0   6.20   1.0  0.507  6.951   88.5  2.8617   8.0  307.0
# 505  2.92400   0.0  19.58   0.0  0.605  6.101   93.0  2.2834   5.0  403.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       21.0  396.90  18.72  15.2
# ...

# %%
X = data.drop(columns=["MEDV"]).to_numpy()[480:]
Y = data.MEDV.to_numpy()[480:]

# %%
scale = StandardScaler()

# %%
X_normal = scale.encoder(X)

# %%
Y_predict = model.predict(X_normal)
cur_result = K.get_value(r2_score(K.constant(Y), Y_predict))
expected_one = r2_score_sk(Y, Y_predict)
# Out:
# 1/1 [==============================] - 0s 89ms/step

# %%
Y_decode = scale.decoder(Y_predict).ravel()

# %%
for yd,yr in zip(Y_decode,Y):
    print("Bashorat: ",yd,"\tHaqiqiy",yr)
# Out:
# Bashorat:  20.062754 	Haqiqiy 20.9
# Bashorat:  24.241684 	Haqiqiy 28.1
# Bashorat:  35.63308 	Haqiqiy 35.4
# Bashorat:  9.569557 	Haqiqiy 10.2
# Bashorat:  22.187897 	Haqiqiy 24.3
# Bashorat:  38.602074 	Haqiqiy 43.1
# Bashorat:  17.173111 	Haqiqiy 17.6
# Bashorat:  12.143544 	Haqiqiy 15.4
# Bashorat:  18.610508 	Haqiqiy 16.2
# Bashorat:  18.117271 	Haqiqiy 27.1
# Bashorat:  20.075775 	Haqiqiy 21.4
# Bashorat:  19.811935 	Haqiqiy 21.5
# Bashorat:  21.540184 	Haqiqiy 22.4
# Bashorat:  25.442474 	Haqiqiy 25.0
# Bashorat:  19.214949 	Haqiqiy 16.6
# Bashorat:  18.968674 	Haqiqiy 18.6
# Bashorat:  26.440145 	Haqiqiy 22.0
# Bashorat:  37.83524 	Haqiqiy 42.8
# Bashorat:  36.495346 	Haqiqiy 35.1
# Bashorat:  19.018799 	Haqiqiy 21.5
# Bashorat:  35.624363 	Haqiqiy 36.0
# Bashorat:  36.211334 	Haqiqiy 21.9
# Bashorat:  23.941254 	Haqiqiy 24.1
# Bashorat:  48.47467 	Haqiqiy 50.0
# Bashorat:  28.579689 	Haqiqiy 26.7
# Bashorat:  19.72802 	Haqiqiy 25.0
